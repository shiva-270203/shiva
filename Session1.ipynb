# %% [markdown]
# **Step-1:import packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Step-2:Create a Dataframe using list**

# %%
Names=['Ramesh','Suresh','Sathish']
# pd.DataFrme(dta,index,columns)
pd.DataFrame(Names)
# Out:
#          0
# 0   Ramesh
# 1   Suresh
# 2  Sathish

# %%
import pandas as pd
Names=['Shiva','Bhanu','bharath']
pd.DataFrame(Names)
# Out:
#          0
# 0    Shiva
# 1    Bhanu
# 2  bharath

# %% [markdown]
# **Step-3:Name the column**

# %%
Names=['Ramesh','Suresh','Sathish']
pd.DataFrame(Names,'NAME') # W
pd.DataFrame(Names,columns='NAME')  # W
pd.DataFrame(Names,['NAME']) # w
pd.DataFrame(Names,columns=['NAME']) # Right

# %%
Names=['Ramesh','Suresh','Sathish']
pd.DataFrame(Names,columns=['NAME'])
# Out:
#       NAME
# 0   Ramesh
# 1   Suresh
# 2  Sathish

# %%
import pandas as pd
Names=['Shiva','Bhanu','bharath']
pd.DataFrame(Names,columns=['NAME'])
# Out:
#       NAME
# 0    Shiva
# 1    Bhanu
# 2  bharath

# %% [markdown]
# **Step-4:Change the index**

# %%
Names=['Ramesh','Suresh','Sathish']
pd.DataFrame(Names,index=['A','B','C'],columns=['NAME'])
# Out:
#       NAME
# A   Ramesh
# B   Suresh
# C  Sathish

# %%
import pandas as pd
Names=['Shiva','Bhanu','bharath']
pd.DataFrame(Names,index=['A','B','C'],columns=['Name'])
# Out:
#       Name
# A    Shiva
# B    Bhanu
# C  bharath

# %% [markdown]
# **Step-5:Two columns**

# %%
Names=['Ramesh','Suresh','Sathish']
Age=[20,22,24]
pd.DataFrame(zip(Names,Age))
# Out:
#          0   1
# 0   Ramesh  20
# 1   Suresh  22
# 2  Sathish  24

# %%
import pandas as pd
Names=['Shiva','Bhanu','Bharath']
Age=[20,25,30]
pd.DataFrame(zip(Names,Age))
# Out:
#          0   1
# 0    Shiva  20
# 1    Bhanu  25
# 2  Bharath  30

# %%
import pandas as pd
Name=['Sumanth','Shiva','Vijith']
Age=[30,23,32]
pd.DataFrame(zip(Name,Age),columns=['Name','Age'],index=['A','B','C'])
# Out:
#       Name  Age
# A  Sumanth   30
# B    Shiva   23
# C   Vijith   32

# %%
Names=['Ramesh','Suresh','Sathish']
Age=[20,22,24]
data=zip(Names,Age)
cols=['Names','Age']
pd.DataFrame(data,columns=cols)
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
import pandas as pd
Name=['shiva','sai','nani']
age=[20,21,24]
city=['hyd','mum','pune']
data=zip(Name,age,city)
cols=['Name','Age','City']
pd.DataFrame(data,columns=cols)
# Out:
#     Name  Age  City
# 0  shiva   20   hyd
# 1    sai   21   mum
# 2   nani   24  pune

# %% [markdown]
# **Step-6:Add the data to empty dataframe**

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Sathish']
df['Age']=[20,22,24]
df
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %%
import pandas as pd
df=pd.DataFrame()
df['Name']=['Ramesh','Suresh','Sathish']
df['Age']=[20,22,24]
df['City']=['Hyd','Delhi','Up']
df
# Out:
#       Name  Age   City
# 0   Ramesh   20    Hyd
# 1   Suresh   22  Delhi
# 2  Sathish   24     Up

# %%
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Sathish']
df['Age']=[20,22,24]
df
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   22
# 2  Sathish   24

# %% [markdown]
# **Step-7: Add the column to existed dataframe**

# %%
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Sathish']
df['Age']=[20,22,24]
df['City']=['Pune','Mumbai','Hyderabad']
df
# Out:
#      Names  Age       City
# 0   Ramesh   20       Pune
# 1   Suresh   22     Mumbai
# 2  Sathish   24  Hyderabad

# %%
import pandas as pd
Name=['Sumanth','Shiva','Vijith']
Age=[30,23,32]
City=['Hyd','Wng','Ngk']
pd.DataFrame(zip(Name,Age,City),columns=['Name','Age','City'],index=['A','B','C'])
# Out:
#       Name  Age City
# A  Sumanth   30  Hyd
# B    Shiva   23  Wng
# C   Vijith   32  Ngk

# %% [markdown]
# **Step-8:Rename the column**

# %%
# I want to rename 'City' to 'city'
# df.rename(mapper,index,columns,axis,inplace)
d={'City':'city'}
df.rename(columns=d)
# Out:
#      Names  Age       city
# 0   Ramesh   20       Pune
# 1   Suresh   22     Mumbai
# 2  Sathish   24  Hyderabad

# %%
d={'Age':'age'}
df.rename(columns=d)
# Out:
#      Names  age       City
# 0   Ramesh   20       Pune
# 1   Suresh   22     Mumbai
# 2  Sathish   24  Hyderabad

# %%
d={'City':'city'}  # Column
df.rename(d)       # index
df.rename(d,axis=0) # index
df.rename(d,axis=1)  # col == work
df.rename(index=d)  # in
df.rename(columns=d) # column == work
# Out:
#      Names  Age       city
# 0   Ramesh   20       Pune
# 1   Suresh   22     Mumbai
# 2  Sathish   24  Hyderabad

# %%
df.columns=['names','age','City']

# %%
df.index=['A','B','C']

# %%
df
# Out:
#      names  age       City
# A   Ramesh   20       Pune
# B   Suresh   22     Mumbai
# C  Sathish   24  Hyderabad

# %% [markdown]
# **Step-9:Drop the column**

# %%
# I want to drop 'City' column'
df.drop('City',axis=1)
# Out:
#      names  age
# A   Ramesh   20
# B   Suresh   22
# C  Sathish   24

# %%
df.drop(columns=['City'])
# Out:
#      names  age
# A   Ramesh   20
# B   Suresh   22
# C  Sathish   24

# %%
df.drop(index=['C'])
# Out:
#     names  age    City
# A  Ramesh   20    Pune
# B  Suresh   22  Mumbai

# %%
df.drop('City',axis=1,inplace=True)

# %%
df
# Out:
#      names  age
# A   Ramesh   20
# B   Suresh   22
# C  Sathish   24

# %%
df.drop(index=['C'],axis=1,inplace=True)

# %%
df
# Out:
#     names  age
# A  Ramesh   20
# B  Suresh   22

# %%
df.drop('city',axis=1,inplace=True)

# %%
df.drop('City')  # error
df.drop('City',axis=0)  # error
df.drop(index=['City']) # error
df.drop('City',axis=1)  # work
df.drop(columns=['City']) # work

# %%
import pandas as pd
Name=['Shiva','Sumanth','Sai']
pd.DataFrame(Name)
# Out:
#          0
# 0    Shiva
# 1  Sumanth
# 2      Sai

# %%
import pandas as pd
Name=['Shiva','Sumanth','Sai']
Age=[20,21,25]
pd.DataFrame(zip(Name,Age))
# Out:
#          0   1
# 0    Shiva  20
# 1  Sumanth  21
# 2      Sai  25

# %%
import pandas as pd
Name=['Shiva','Sumanth','Sai']
Age=[20,21,25]
pd.DataFrame(zip(Name,Age),columns=['Name','Age'])
# Out:
#       Name  Age
# 0    Shiva   20
# 1  Sumanth   21
# 2      Sai   25

# %%
import pandas as pd
Name=['Nani','Shiva','Mani']
Age=[23,23,10]
pd.DataFrame(zip(Name,Age),columns=['Names','Ages'],index=['A','B','C'])
# Out:
#    Names  Ages
# A   Nani    23
# B  Shiva    23
# C   Mani    10

# %%
import pandas as pd
Name=['Nani','Shiva','Mani']
Age=[23,23,11]
City=['Hyderabad','Nagarkurnool','Warangal']
pd.DataFrame(zip(Name,Age,City),columns=['Names','Ages','City'],index=['A','B','C'])
# Out:
#    Names  Ages          City
# A   Nani    23     Hyderabad
# B  Shiva    23  Nagarkurnool
# C   Mani    11      Warangal

# %%
import pandas as pd
df=pd.DataFrame()
df['Name']=['Nani','Shiva','Mani']
df['Age']=[23,23,11]
df['City']=['Hyd','Ngk','Wng']
df
# Out:
#     Name  Age City
# 0   Nani   23  Hyd
# 1  Shiva   23  Ngk
# 2   Mani   11  Wng

# %%
df.drop(columns=['City'])
# Out:
#     Name  Age
# 0   Nani   23
# 1  Shiva   23
# 2   Mani   11

# %%
d={'City':'city'}
df.rename(columns=d)
# Out:
#     Name  Age city
# 0   Nani   23  Hyd
# 1  Shiva   23  Ngk
# 2   Mani   11  Wng

# %%
df.rename(d,axis=1)
# Out:
#     Name  Age city
# 0   Nani   23  Hyd
# 1  Shiva   23  Ngk
# 2   Mani   11  Wng

# %%
import pandas as pd
Names=['Ramesh','Suresh','Sathish']
City=['Hyd','Blr','Pune']
Age=[20,22,24]
data=zip(Names,City,Age)
df=pd.DataFrame(data,
             index=['A','B','C'],
             columns=['Names','City','Age'])
#####################################################
df.drop('City',axis=1,inplace=True)
df.drop('C',inplace=True)

# %%
df
# Out:
#     Names  Age
# A  Ramesh   20
# B  Suresh   22

# %% [markdown]
# - creating a dataframe
#
# - Name the column
#
# - Change the Index
#
# - add the columns
#
# - add the data to empty dataframe
#
# - add the column to existing dataframe
#
# - rename the column
#
# - rename all the column and all the index at a time
#
# - drop the column
#
# - drop the index

# %%
# create a dataframe
import pandas as pd
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Sathish']
df['Age']=[20,22,24]
df['City']=['Hyd','Blr','Pune']
df
# Out:
#      Names  Age  City
# 0   Ramesh   20   Hyd
# 1   Suresh   22   Blr
# 2  Sathish   24  Pune

# %% [markdown]
# **Step-10:replace**

# %%
# df.replace(to_replace,value)
df.replace('Hyd','Chennai') # inplace not happend so it will not overwrite
# Out:
#      Names  Age     City
# 0   Ramesh   20  Chennai
# 1   Suresh   22      Blr
# 2  Sathish   24     Pune

# %%
df
# Out:
#      Names  Age  City
# 0   Ramesh   20   Hyd
# 1   Suresh   22   Blr
# 2  Sathish   24  Pune

# %%
df['Names']='Mahesh'
df['Age']=24
df['City']='Hyd'

# %%
df
# Out:
#     Names  Age City
# 0  Mahesh   24  Hyd
# 1  Mahesh   24  Hyd
# 2  Mahesh   24  Hyd

# %%
import pandas as pd
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Sathish','Mahesh']
df['Age']=[20,22,24,24]
df['City']=['Hyd','Blr','Pune','Hyd']
df
# Out:
#      Names  Age  City
# 0   Ramesh   20   Hyd
# 1   Suresh   22   Blr
# 2  Sathish   24  Pune
# 3   Mahesh   24   Hyd

# %%
df.replace('Hyd','Chennai')
# Out:
#      Names  Age     City
# 0   Ramesh   20  Chennai
# 1   Suresh   22      Blr
# 2  Sathish   24     Pune
# 3   Mahesh   24  Chennai

# %%
df['Marks']=[25,24,23,22]

# %%
df
# Out:
#      Names  Age  City  Marks
# 0   Ramesh   20   Hyd     25
# 1   Suresh   22   Blr     24
# 2  Sathish   24  Pune     23
# 3   Mahesh   24   Hyd     22

# %%
df.replace(24,20)
# Out:
#      Names  Age  City  Marks
# 0   Ramesh   20   Hyd     25
# 1   Suresh   22   Blr     20
# 2  Sathish   20  Pune     23
# 3   Mahesh   20   Hyd     22

# %%
# all the data in same will change
# all the column data will change

df
# Out:
#      Names  Age  City  Marks
# 0   Ramesh   20   Hyd     25
# 1   Suresh   22   Blr     24
# 2  Sathish   24  Pune     23
# 3   Mahesh   24   Hyd     22

# %%
df['Marks'].replace(24,20,inplace=True)
# Out:
# C:\Users\Pebbeti Shiva prasad\AppData\Local\Temp\ipykernel_34860\602866676.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].replace(24,20,inplace=True)

# %%
df
# Out:
#      Names  Age  City  Marks
# 0   Ramesh   20   Hyd     25
# 1   Suresh   22   Blr     20
# 2  Sathish   24  Pune     23
# 3   Mahesh   24   Hyd     22

# %%
# I want to change city name to Chennai
# for the candidates who has age = 24

# %% [markdown]
# **Step11-np.where**

# %%
import numpy as np

# %%
np.where(condition,True,False)
age==24
Chennai
Nochange
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 np.where(condition,True,False)
#       2 age==24
#       3 Chennai
#
# NameError: name 'condition' is not defined

# %%
df['City']=np.where(con,true,false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df['City']=np.where(con,true,false)
#
# NameError: name 'con' is not defined

# %%
df
# Out:
#      Names  Age  City  Marks
# 0   Ramesh   20   Hyd     25
# 1   Suresh   22   Blr     20
# 2  Sathish   24  Pune     23
# 3   Mahesh   24   Hyd     22

# %%
# Big4
# Delloitte, EY, PWC,KPMG
#    SQL PANDAS 
# MAANG  : Micr AMA  APPL NV G
#          developer 
#          Skills DATA Structures
# create products 
#  SQL vs Pandas

# %% [markdown]
# **Step-12:Append a row**

# %%
df
# Out:
#      Names  Age  City  Marks
# 0   Ramesh   20   Hyd     25
# 1   Suresh   22   Blr     20
# 2  Sathish   24  Pune     23
# 3   Mahesh   24   Hyd     22

# %% [markdown]
# **loc-iloc**

# %%
df.loc[rows,columns]
  rows are index numbers similar to list slice
  l[start:stop:step]
  column are names any column name we can provide
df.iloc[rows,columns]
  rows and columns are index numbers similar to list slice
  l[start:stop:step]

# %%
rows=[1,2,3]
cols=['Age','City']
df.loc[rows,cols]
# Out:
#    Age  City
# 1   22   Blr
# 2   24  Pune
# 3   24   Hyd

# %%
df
# Out:
#      Names  Age  City  Marks
# 0   Ramesh   20   Hyd     25
# 1   Suresh   22   Blr     20
# 2  Sathish   24  Pune     23
# 3   Mahesh   24   Hyd     22

# %%
rows=[1,2,3]
cols=[1,2]
df.iloc[rows,cols]
# Out:
#    Age  City
# 1   22   Blr
# 2   24  Pune
# 3   24   Hyd

# %%
cols=['Age','City']
df.loc[1:3,cols]
# Out:
#    Age  City
# 1   22   Blr
# 2   24  Pune
# 3   24   Hyd

# %%
df.loc[len(df)]=['Anish',26,'Mumbai',25]

# %%
df
# Out:
#      Names  Age    City  Marks
# 0   Ramesh   20     Hyd     25
# 1   Suresh   22     Blr     20
# 2  Sathish   24    Pune     23
# 3   Mahesh   24     Hyd     22
# 4    Anish   26  Mumbai     25

# %% [markdown]
# **Step-13:How to save the dataframe**

# %%
# directory : where is the file available
# name      : what is the name of the file
# extension : what is the type of the file 

####################################
#      SAME PYTHON LOCATION        #
# name      : what is the name of the file
# extension : what is the type of the file 

# dataframe variable = df
# name : student
# exten : .csv  and .xlsx 

df.to_csv('student.csv')

# %%
pd.read_csv('student.csv')
# Out:
#    Unnamed: 0    Names  Age    City  Marks
# 0           0   Ramesh   20     Hyd     25
# 1           1   Suresh   22     Blr     20
# 2           2  Sathish   24    Pune     23
# 3           3   Mahesh   24     Hyd     22
# 4           4    Anish   26  Mumbai     25

# %% [markdown]
# **Step-14:Ignore index**

# %%
df.to_csv('student.csv',index=False)

# %%
pd.read_csv('student.csv')
# Out:
#      Names  Age    City  Marks
# 0   Ramesh   20     Hyd     25
# 1   Suresh   22     Blr     20
# 2  Sathish   24    Pune     23
# 3   Mahesh   24     Hyd     22
# 4    Anish   26  Mumbai     25

# %%
df.to_excel('student.xlsx')

# %%
pd.read_excel('student.xlsx')
# Out:
#    Unnamed: 0    Names  Age    City  Marks
# 0           0   Ramesh   20     Hyd     25
# 1           1   Suresh   22     Blr     20
# 2           2  Sathish   24    Pune     23
# 3           3   Mahesh   24     Hyd     22
# 4           4    Anish   26  Mumbai     25

# %%
# take a new notebook
# in your datafiles
#   visadataset
#   bankdataset pls load that

# %%
import pandas as pd
Name=['shiva','bharath','mani']
Age=[24,14,11]
City=['klk','Mmd','ngkl']
data=zip(Name,Age,City)
cols=['Name','Age','City']
pd.DataFrame(data,columns=cols,index=['A','B','C'])
# Out:
#       Name  Age  City
# A    shiva   24   klk
# B  bharath   14   Mmd
# C     mani   11  ngkl

# %%
df['marks']=[95,96,98]
df
# Out:
#       Name  Age   City  marks
# 0   Ramesh   20    Hyd     95
# 1   Suresh   22  Delhi     96
# 2  Sathish   24     Up     98

# %%
d={'City':'city'}
df.rename(columns=d)
# Out:
#       Name  Age   city  marks
# 0   Ramesh   20    Hyd     95
# 1   Suresh   22  Delhi     96
# 2  Sathish   24     Up     98

# %%
df.replace(22,23)
# Out:
#       Name  Age   City  marks
# 0   Ramesh   20    Hyd     95
# 1   Suresh   23  Delhi     96
# 2  Sathish   24     Up     98

# %%
import pandas as pd
df=pd.DataFrame()
df['Name']=['shiva','bharath','mani']
df['Age']=[24,14,11]
df['City']=['Klk','MMD','NGKL']

# %%
df['Marks']=[23,21,18]
df
# Out:
#       Name  Age  City  Marks
# 0    shiva   24   Klk     23
# 1  bharath   14   MMD     21
# 2     mani   11  NGKL     18
